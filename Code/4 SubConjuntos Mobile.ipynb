# %% [markdown]
# ## Entrenamiento de DensetNet121

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2  # <- CAMBIO: usar MobileNetV2

# Directorios de las imágenes
ruta_violentas = "../dataset/dataset1/violencia"
ruta_no_violentas = "../dataset/dataset1/no_violencia"

# Función para cargar las imágenes y sus etiquetas
def load_images_and_labels(ruta_violentas, ruta_no_violentas):
    imagenes = []
    etiquetas = []
    
    # Cargar imágenes de la carpeta de violencia
    for filename in os.listdir(ruta_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de la carpeta de no violencia
    for filename in os.listdir(ruta_no_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_no_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    # Convertir las listas a arrays de numpy
    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)
    
    # Normalizar las imágenes (escalarlas entre 0 y 1)
    imagenes = imagenes / 255.0
    
    return imagenes, etiquetas

# Crear el modelo MobileNetV2 preentrenado (solo este bloque cambia)
def create_model():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))  # <- CAMBIO
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(2, activation='softmax')(x)  # Para clasificación con 2 clases
    model = Model(inputs=base_model.input, outputs=predictions)

    for layer in base_model.layers:
        layer.trainable = False  # Congelar las capas base para preentrenar

    model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Función de entrenamiento
def train_model(model, X_train, y_train, X_val, y_val, epochs=300, batch_size=16):
    model_history = model.fit(
        X_train, y_train,
        epochs=epochs,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        callbacks=[ 
            tf.keras.callbacks.EarlyStopping(patience=10),
            tf.keras.callbacks.ModelCheckpoint('modelo_mejorado_MobileNetV2.h5', save_best_only=True),
            tf.keras.callbacks.TensorBoard(log_dir='./logs')  # Para seguimiento con TensorBoard
        ]
    )
    return model_history

# Visualización de los resultados de entrenamiento
def plot_training_history(model_history):
    # Graficar precisión
    plt.plot(model_history.history['accuracy'])
    plt.plot(model_history.history['val_accuracy'])
    plt.title('Precisión durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Precisión')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

    # Graficar pérdida
    plt.plot(model_history.history['loss'])
    plt.plot(model_history.history['val_loss'])
    plt.title('Pérdida durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

# Matriz de confusión
def plot_confusion_matrix(model, X_val, y_val):
    preds = model.predict(X_val)
    predicted_labels = np.argmax(preds, axis=1)
    true_labels = np.argmax(y_val, axis=1)

    cm = confusion_matrix(true_labels, predicted_labels)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['No Violencia', 'Violencia'], yticklabels=['No Violencia', 'Violencia'])
    plt.xlabel('Predicción')
    plt.ylabel('Real')
    plt.show()

# Cargar las imágenes y etiquetas
imagenes, etiquetas = load_images_and_labels(ruta_violentas, ruta_no_violentas)

# Dividir en conjunto de entrenamiento y validación (80% - 20%)
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(imagenes, etiquetas, test_size=0.2, random_state=2)

# Crear el modelo preentrenado
model = create_model()

# Entrenar el modelo
model_history = train_model(model, X_train, y_train, X_val, y_val)

# Graficar los resultados de entrenamiento y validación
plot_training_history(model_history)

# Graficar la matriz de confusión del conjunto de validación
plot_confusion_matrix(model, X_val, y_val)

# Guardar el modelo entrenado
model.save('Modelo_MobileNetV2.h5')  # (dejé el nombre exactamente igual como pediste)
print("Modelo guardado como 'MobileNetV2'")
# Out:
# c:\Users\Frank Prime\anaconda3\envs\tf210vit\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/300
# 300/300 [==============================] - 12s 23ms/step - loss: 0.2280 - accuracy: 0.9119 - val_loss: 0.1035 - val_accuracy: 0.9725
# Epoch 2/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0801 - accuracy: 0.9825 - val_loss: 0.0615 - val_accuracy: 0.9858
# Epoch 3/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0425 - accuracy: 0.9927 - val_loss: 0.0406 - val_accuracy: 0.9892
# Epoch 4/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0229 - accuracy: 0.9981 - val_loss: 0.0261 - val_accuracy: 0.9925
# Epoch 5/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0147 - accuracy: 0.9994 - val_loss: 0.0195 - val_accuracy: 0.9942
# Epoch 6/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0087 - accuracy: 0.9998 - val_loss: 0.0170 - val_accuracy: 0.9958
# Epoch 7/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9950
# Epoch 8/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9975
# Epoch 9/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9983
# Epoch 10/300
# 300/300 [==============================] - 5s 18ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9983
# Epoch 11/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 12/300
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 13/300
# 300/300 [==============================] - 6s 19ms/step - loss: 9.9396e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 14/300
# 300/300 [==============================] - 6s 19ms/step - loss: 7.7828e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9992
# Epoch 15/300
# 300/300 [==============================] - 6s 19ms/step - loss: 5.9687e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9992
# Epoch 16/300
# 300/300 [==============================] - 6s 19ms/step - loss: 5.0097e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 17/300
# 300/300 [==============================] - 5s 18ms/step - loss: 4.0786e-04 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 0.9992
# Epoch 18/300
# 300/300 [==============================] - 6s 19ms/step - loss: 3.1934e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9983
# Epoch 19/300
# 300/300 [==============================] - 6s 19ms/step - loss: 2.5920e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 20/300
# 300/300 [==============================] - 6s 19ms/step - loss: 2.1313e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9992
# Epoch 21/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.7721e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9992
# Epoch 22/300
# 300/300 [==============================] - 6s 19ms/step - loss: 1.4541e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 23/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.1711e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 24/300
# 300/300 [==============================] - 5s 17ms/step - loss: 1.0062e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 25/300
# 300/300 [==============================] - 6s 19ms/step - loss: 8.1182e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 26/300
# 300/300 [==============================] - 6s 19ms/step - loss: 6.6398e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 27/300
# 300/300 [==============================] - 6s 19ms/step - loss: 5.5333e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 28/300
# 300/300 [==============================] - 6s 19ms/step - loss: 4.6404e-05 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 29/300
# 300/300 [==============================] - 6s 19ms/step - loss: 3.8795e-05 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 30/300
# 300/300 [==============================] - 6s 19ms/step - loss: 3.2277e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 31/300
# 300/300 [==============================] - 6s 19ms/step - loss: 2.6623e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 32/300
# 300/300 [==============================] - 6s 19ms/step - loss: 2.2340e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 33/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.8650e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 34/300
# 300/300 [==============================] - 6s 19ms/step - loss: 1.5983e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 35/300
# 300/300 [==============================] - 6s 19ms/step - loss: 1.3228e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 36/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.1008e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 37/300
# 300/300 [==============================] - 5s 17ms/step - loss: 9.3819e-06 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 38/300
# 300/300 [==============================] - 5s 17ms/step - loss: 7.8233e-06 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 39/300
# 300/300 [==============================] - 5s 18ms/step - loss: 6.6351e-06 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 40/300
# 300/300 [==============================] - 5s 18ms/step - loss: 5.6190e-06 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 41/300
# 300/300 [==============================] - 6s 18ms/step - loss: 4.7164e-06 - accuracy: 1.0000 - val_loss: 9.3293e-04 - val_accuracy: 1.0000
# Epoch 42/300
# 300/300 [==============================] - 5s 18ms/step - loss: 4.0639e-06 - accuracy: 1.0000 - val_loss: 8.1620e-04 - val_accuracy: 1.0000
# Epoch 43/300
# 300/300 [==============================] - 5s 17ms/step - loss: 3.3237e-06 - accuracy: 1.0000 - val_loss: 9.3315e-04 - val_accuracy: 1.0000
# Epoch 44/300
# 300/300 [==============================] - 5s 18ms/step - loss: 2.8847e-06 - accuracy: 1.0000 - val_loss: 6.8900e-04 - val_accuracy: 1.0000
# Epoch 45/300
# 300/300 [==============================] - 5s 17ms/step - loss: 2.4336e-06 - accuracy: 1.0000 - val_loss: 7.7921e-04 - val_accuracy: 1.0000
# Epoch 46/300
# 300/300 [==============================] - 5s 17ms/step - loss: 2.0468e-06 - accuracy: 1.0000 - val_loss: 7.0833e-04 - val_accuracy: 1.0000
# Epoch 47/300
# 300/300 [==============================] - 5s 17ms/step - loss: 1.7738e-06 - accuracy: 1.0000 - val_loss: 8.2079e-04 - val_accuracy: 1.0000
# Epoch 48/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.5294e-06 - accuracy: 1.0000 - val_loss: 6.8430e-04 - val_accuracy: 1.0000
# Epoch 49/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.2562e-06 - accuracy: 1.0000 - val_loss: 6.2879e-04 - val_accuracy: 1.0000
# Epoch 50/300
# 300/300 [==============================] - 5s 17ms/step - loss: 1.0694e-06 - accuracy: 1.0000 - val_loss: 7.9725e-04 - val_accuracy: 1.0000
# Epoch 51/300
# 300/300 [==============================] - 5s 18ms/step - loss: 9.3976e-07 - accuracy: 1.0000 - val_loss: 5.6905e-04 - val_accuracy: 1.0000
# Epoch 52/300
# 300/300 [==============================] - 5s 18ms/step - loss: 8.0814e-07 - accuracy: 1.0000 - val_loss: 4.9051e-04 - val_accuracy: 1.0000
# Epoch 53/300
# 300/300 [==============================] - 5s 18ms/step - loss: 6.7934e-07 - accuracy: 1.0000 - val_loss: 4.7932e-04 - val_accuracy: 1.0000
# Epoch 54/300
# 300/300 [==============================] - 5s 16ms/step - loss: 5.9108e-07 - accuracy: 1.0000 - val_loss: 5.0997e-04 - val_accuracy: 1.0000
# Epoch 55/300
# 300/300 [==============================] - 5s 18ms/step - loss: 5.0684e-07 - accuracy: 1.0000 - val_loss: 4.0267e-04 - val_accuracy: 1.0000
# Epoch 56/300
# 300/300 [==============================] - 5s 17ms/step - loss: 4.3568e-07 - accuracy: 1.0000 - val_loss: 3.7607e-04 - val_accuracy: 1.0000
# Epoch 57/300
# 300/300 [==============================] - 5s 16ms/step - loss: 3.7486e-07 - accuracy: 1.0000 - val_loss: 3.8869e-04 - val_accuracy: 1.0000
# Epoch 58/300
# 300/300 [==============================] - 5s 17ms/step - loss: 3.1931e-07 - accuracy: 1.0000 - val_loss: 4.6685e-04 - val_accuracy: 1.0000
# Epoch 59/300
# 300/300 [==============================] - 5s 18ms/step - loss: 2.7485e-07 - accuracy: 1.0000 - val_loss: 3.5606e-04 - val_accuracy: 1.0000
# Epoch 60/300
# 300/300 [==============================] - 5s 16ms/step - loss: 2.4165e-07 - accuracy: 1.0000 - val_loss: 3.6725e-04 - val_accuracy: 1.0000
# Epoch 61/300
# 300/300 [==============================] - 5s 17ms/step - loss: 2.1324e-07 - accuracy: 1.0000 - val_loss: 3.5120e-04 - val_accuracy: 1.0000
# Epoch 62/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.8299e-07 - accuracy: 1.0000 - val_loss: 3.1189e-04 - val_accuracy: 1.0000
# Epoch 63/300
# 300/300 [==============================] - 5s 16ms/step - loss: 1.5589e-07 - accuracy: 1.0000 - val_loss: 3.1745e-04 - val_accuracy: 1.0000
# Epoch 64/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.3689e-07 - accuracy: 1.0000 - val_loss: 2.6113e-04 - val_accuracy: 1.0000
# Epoch 65/300
# 300/300 [==============================] - 5s 17ms/step - loss: 1.1976e-07 - accuracy: 1.0000 - val_loss: 3.2511e-04 - val_accuracy: 1.0000
# Epoch 66/300
# 300/300 [==============================] - 5s 16ms/step - loss: 1.0525e-07 - accuracy: 1.0000 - val_loss: 2.8561e-04 - val_accuracy: 1.0000
# Epoch 67/300
# 300/300 [==============================] - 5s 16ms/step - loss: 9.1419e-08 - accuracy: 1.0000 - val_loss: 3.0078e-04 - val_accuracy: 1.0000
# Epoch 68/300
# 300/300 [==============================] - 5s 16ms/step - loss: 7.9994e-08 - accuracy: 1.0000 - val_loss: 3.0683e-04 - val_accuracy: 1.0000
# Epoch 69/300
# 300/300 [==============================] - 5s 17ms/step - loss: 7.1178e-08 - accuracy: 1.0000 - val_loss: 3.3896e-04 - val_accuracy: 1.0000
# Epoch 70/300
# 300/300 [==============================] - 5s 18ms/step - loss: 6.3529e-08 - accuracy: 1.0000 - val_loss: 2.7137e-04 - val_accuracy: 1.0000
# Epoch 71/300
# 300/300 [==============================] - 6s 19ms/step - loss: 5.5556e-08 - accuracy: 1.0000 - val_loss: 2.5004e-04 - val_accuracy: 1.0000
# Epoch 72/300
# 300/300 [==============================] - 6s 19ms/step - loss: 4.8776e-08 - accuracy: 1.0000 - val_loss: 2.4260e-04 - val_accuracy: 1.0000
# Epoch 73/300
# 300/300 [==============================] - 5s 17ms/step - loss: 4.2841e-08 - accuracy: 1.0000 - val_loss: 2.8213e-04 - val_accuracy: 1.0000
# Epoch 74/300
# 300/300 [==============================] - 6s 19ms/step - loss: 3.8420e-08 - accuracy: 1.0000 - val_loss: 2.3157e-04 - val_accuracy: 1.0000
# Epoch 75/300
# 300/300 [==============================] - 5s 17ms/step - loss: 3.4024e-08 - accuracy: 1.0000 - val_loss: 2.3668e-04 - val_accuracy: 1.0000
# Epoch 76/300
# 300/300 [==============================] - 5s 18ms/step - loss: 3.0225e-08 - accuracy: 1.0000 - val_loss: 2.8909e-04 - val_accuracy: 1.0000
# Epoch 77/300
# 300/300 [==============================] - 6s 19ms/step - loss: 2.7393e-08 - accuracy: 1.0000 - val_loss: 1.8038e-04 - val_accuracy: 1.0000
# Epoch 78/300
# 300/300 [==============================] - 5s 18ms/step - loss: 2.4363e-08 - accuracy: 1.0000 - val_loss: 1.8252e-04 - val_accuracy: 1.0000
# Epoch 79/300
# 300/300 [==============================] - 5s 17ms/step - loss: 2.1880e-08 - accuracy: 1.0000 - val_loss: 2.4660e-04 - val_accuracy: 1.0000
# Epoch 80/300
# 300/300 [==============================] - 5s 17ms/step - loss: 1.9794e-08 - accuracy: 1.0000 - val_loss: 2.1495e-04 - val_accuracy: 1.0000
# Epoch 81/300
# 300/300 [==============================] - 6s 19ms/step - loss: 1.7360e-08 - accuracy: 1.0000 - val_loss: 1.6908e-04 - val_accuracy: 1.0000
# Epoch 82/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.5870e-08 - accuracy: 1.0000 - val_loss: 1.8240e-04 - val_accuracy: 1.0000
# Epoch 83/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.4429e-08 - accuracy: 1.0000 - val_loss: 2.2465e-04 - val_accuracy: 1.0000
# Epoch 84/300
# 300/300 [==============================] - 5s 17ms/step - loss: 1.3212e-08 - accuracy: 1.0000 - val_loss: 1.8568e-04 - val_accuracy: 1.0000
# Epoch 85/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.1772e-08 - accuracy: 1.0000 - val_loss: 1.7653e-04 - val_accuracy: 1.0000
# Epoch 86/300
# 300/300 [==============================] - 5s 18ms/step - loss: 1.0828e-08 - accuracy: 1.0000 - val_loss: 1.8783e-04 - val_accuracy: 1.0000
# Epoch 87/300
# 300/300 [==============================] - 5s 18ms/step - loss: 9.7851e-09 - accuracy: 1.0000 - val_loss: 1.7013e-04 - val_accuracy: 1.0000
# Epoch 88/300
# 300/300 [==============================] - 6s 19ms/step - loss: 9.0152e-09 - accuracy: 1.0000 - val_loss: 1.5199e-04 - val_accuracy: 1.0000
# Epoch 89/300
# 300/300 [==============================] - 5s 17ms/step - loss: 8.3198e-09 - accuracy: 1.0000 - val_loss: 1.9045e-04 - val_accuracy: 1.0000
# Epoch 90/300
# 300/300 [==============================] - 6s 19ms/step - loss: 7.5251e-09 - accuracy: 1.0000 - val_loss: 1.2827e-04 - val_accuracy: 1.0000
# Epoch 91/300
# 300/300 [==============================] - 5s 18ms/step - loss: 6.8545e-09 - accuracy: 1.0000 - val_loss: 1.5360e-04 - val_accuracy: 1.0000
# Epoch 92/300
# 300/300 [==============================] - 5s 18ms/step - loss: 6.5317e-09 - accuracy: 1.0000 - val_loss: 1.5805e-04 - val_accuracy: 1.0000
# Epoch 93/300
# 300/300 [==============================] - 5s 18ms/step - loss: 6.1095e-09 - accuracy: 1.0000 - val_loss: 1.4442e-04 - val_accuracy: 1.0000
# Epoch 94/300
# 300/300 [==============================] - 5s 18ms/step - loss: 5.6128e-09 - accuracy: 1.0000 - val_loss: 1.6170e-04 - val_accuracy: 1.0000
# Epoch 95/300
# 300/300 [==============================] - 5s 17ms/step - loss: 5.1657e-09 - accuracy: 1.0000 - val_loss: 1.5480e-04 - val_accuracy: 1.0000
# Epoch 96/300
# 300/300 [==============================] - 5s 18ms/step - loss: 4.8429e-09 - accuracy: 1.0000 - val_loss: 1.5644e-04 - val_accuracy: 1.0000
# Epoch 97/300
# 300/300 [==============================] - 5s 17ms/step - loss: 4.6690e-09 - accuracy: 1.0000 - val_loss: 1.7555e-04 - val_accuracy: 1.0000
# Epoch 98/300
# 300/300 [==============================] - 5s 17ms/step - loss: 4.1972e-09 - accuracy: 1.0000 - val_loss: 1.7446e-04 - val_accuracy: 1.0000
# Epoch 99/300
# 300/300 [==============================] - 5s 17ms/step - loss: 3.9736e-09 - accuracy: 1.0000 - val_loss: 1.4005e-04 - val_accuracy: 1.0000
# Epoch 100/300
# 300/300 [==============================] - 5s 17ms/step - loss: 3.6508e-09 - accuracy: 1.0000 - val_loss: 1.6504e-04 - val_accuracy: 1.0000
# 38/38 [==============================] - 2s 26ms/step
# Modelo guardado como 'MobileNetV2'

# %%
import numpy as np
import os
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Directorios de las imágenes de prueba
ruta_test_violencia = "../test2/violencia"
ruta_test_no_violencia = "../test2/no_violencia"

# Función para cargar las imágenes y etiquetas de prueba
def cargar_datos_test(ruta_violencia, ruta_no_violencia):
    imagenes = []
    etiquetas = []

    # Cargar imágenes de violencia
    for filename in os.listdir(ruta_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de no violencia
    for filename in os.listdir(ruta_no_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_no_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)

    return imagenes, etiquetas

# Cargar datos de prueba
X_test, y_test = cargar_datos_test(ruta_test_violencia, ruta_test_no_violencia)

# Cargar el modelo preentrenado (asegúrate de tener el archivo .h5 del modelo final)
modelo_cargado = load_model("modelo_mejorado_MobileNetV2.h5")

# Normalizar las imágenes de prueba
X_test = X_test / 255.0  # Normalizar las imágenes de prueba

# Realizar predicciones con el modelo cargado
predicciones = modelo_cargado.predict(X_test)

# Convertir las predicciones a las clases (1 para violencia, 0 para no violencia)
predicciones_clase = np.argmax(predicciones, axis=1)
y_test_clase = np.argmax(y_test, axis=1)

# Calcular la matriz de confusión
matriz_confusion = confusion_matrix(y_test_clase, predicciones_clase)

# Imprimir la matriz de confusión
print("Matriz de Confusión:")
print(matriz_confusion)

# Graficar la matriz de confusión
plt.figure(figsize=(6, 6))
sns.heatmap(matriz_confusion, annot=True, fmt="d", cmap="Blues", xticklabels=["No Violencia", "Violencia"], yticklabels=["No Violencia", "Violencia"])
plt.title("Matriz de Confusión")
plt.ylabel('Clase Verdadera')
plt.xlabel('Clase Predicha')
plt.show()

# Calcular precisión, recall, f1-score (opcional)
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_clase, predicciones_clase)
recall = recall_score(y_test_clase, predicciones_clase)
f1 = f1_score(y_test_clase, predicciones_clase)

print(f"Precisión: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# 138/138 [==============================] - 9s 39ms/step
# Matriz de Confusión:
# [[1508  692]
#  [ 493 1707]]
# Precisión: 0.71
# Recall: 0.78
# F1-Score: 0.74

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Función para cargar las imágenes y etiquetas de prueba
def cargar_datos_test(ruta_violencia, ruta_no_violencia, img_size):
    imagenes = []
    etiquetas = []

    for filename in os.listdir(ruta_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_violencia, filename), target_size=img_size)
            imagen = img_to_array(imagen) / 255.0  # Normalizar
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    for filename in os.listdir(ruta_no_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_no_violencia, filename), target_size=img_size)
            imagen = img_to_array(imagen) / 255.0  # Normalizar
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    return np.array(imagenes), np.array(etiquetas)

# Función para seleccionar muestras según la categoría especificada
def seleccionar_muestras(predicciones, tipo):
    media_pred = np.mean(predicciones)
    std_pred = np.std(predicciones)

    if tipo == "safe":
        # Umbral fijo para 'safe': seleccionamos ejemplos con certeza alta (mayor a 0.9) o baja (menor a 0.1)
        umbral_inf = 0.0
        umbral_sup = 1.0
        indices_seleccionados = np.where((predicciones >= 0.9) | (predicciones <= 0.1))[0]
        print(f"\n--- Muestras {tipo} ---")
        print(f"Umbral fijo para {tipo}: ({umbral_inf}, {umbral_sup})")
        print("Explicación: Seleccionamos muestras con alta certeza de pertenecer a una clase (violencia o no violencia).")
    elif tipo == "border":
        # Umbral fijo para 'border': seleccionamos ejemplos con certeza media (entre 0.4 y 0.6)
        umbral_inf = 0.4
        umbral_sup = 0.6
        indices_seleccionados = np.where((predicciones >= umbral_inf) & (predicciones <= umbral_sup))[0]
        print(f"\n--- Muestras {tipo} ---")
        print(f"Umbral calculado para {tipo}: ({umbral_inf}, {umbral_sup})")
        print("Explicación: Seleccionamos muestras con certeza ambigua, donde el modelo no tiene una fuerte preferencia.")
    else:  # "average"
        umbral_inf = max(0.0, media_pred - std_pred)
        umbral_sup = min(1.0, media_pred + std_pred)
        indices_seleccionados = np.where((predicciones >= umbral_inf) & (predicciones <= umbral_sup))[0]
        print(f"\n--- Muestras {tipo} ---")
        print(f"Umbral calculado para {tipo}: ({umbral_inf}, {umbral_sup})")
        print("Explicación: Seleccionamos muestras con probabilidad promedio de pertenecer a una clase, dentro de una desviación estándar de la media.")

    print(f"Número de muestras {tipo} seleccionadas: {len(indices_seleccionados)}")
    
    return indices_seleccionados

# Cargar modelo
model_path = "modelo_mejorado_MobileNetV2.h5"
modelo = load_model(model_path)
img_size = (224, 224)

# Cargar datos de prueba
X_test, y_test = cargar_datos_test("../dataset/dataset22/violencia", "../dataset/dataset22/no_violencia", img_size)

# Realizar predicciones
predicciones = modelo.predict(X_test)[:, 0]

# Diccionario de carpetas
carpetas_modelos = {
    "safe": {"violencia": "../tipo3/safe/violencia", "no_violencia": "../tipo3/safe/no_violencia"},
    "border": {"violencia": "../tipo3/border/violencia", "no_violencia": "../tipo3/border/no_violencia"},
    "average": {"violencia": "../tipo3/average/violencia", "no_violencia": "../tipo3/average/no_violencia"}
}

# Procesar cada tipo de muestra
for tipo_muestra in ["safe", "border", "average"]:
    indices_seleccionados = seleccionar_muestras(predicciones, tipo=tipo_muestra)
    
    for i, indice in enumerate(indices_seleccionados):
        imagen = X_test[indice]
        etiqueta = y_test[indice]
        carpeta_destino = carpetas_modelos[tipo_muestra]["violencia" if etiqueta[0] == 1 else "no_violencia"]
        os.makedirs(carpeta_destino, exist_ok=True)
        ruta_destino = os.path.join(carpeta_destino, f"representativa_{i}.jpg")
        tf.keras.preprocessing.image.save_img(ruta_destino, imagen)

# Contar imágenes en cada carpeta
print("\n--- Resumen de imágenes guardadas ---")
for tipo_muestra, rutas in carpetas_modelos.items():
    for categoria, ruta in rutas.items():
        if os.path.exists(ruta):
            image_count = len([f for f in os.listdir(ruta) if f.endswith('.jpg')])
            print(f"{tipo_muestra} - {categoria}: {image_count} imágenes")
        else:
            print(f"{tipo_muestra} - {categoria}: La carpeta no existe.")

print("\nProceso completado. Las imágenes representativas han sido guardadas.")
# Out:
# 175/175 [==============================] - 10s 39ms/step
#
# --- Muestras safe ---
# Umbral fijo para safe: (0.0, 1.0)
# Explicación: Seleccionamos muestras con alta certeza de pertenecer a una clase (violencia o no violencia).
# Número de muestras safe seleccionadas: 5074
#
# --- Muestras border ---
# Umbral calculado para border: (0.4, 0.6)
# Explicación: Seleccionamos muestras con certeza ambigua, donde el modelo no tiene una fuerte preferencia.
# Número de muestras border seleccionadas: 104
#
# --- Muestras average ---
# Umbral calculado para average: (0.0, 0.8931782841682434)
# Explicación: Seleccionamos muestras con probabilidad promedio de pertenecer a una clase, dentro de una desviación estándar de la media.
# Número de muestras average seleccionadas: 3490
#
# --- Resumen de imágenes guardadas ---
# safe - violencia: 2534 imágenes
# safe - no_violencia: 2540 imágenes
# border - violencia: 48 imágenes
# border - no_violencia: 56 imágenes
# average - violencia: 1693 imágenes
# average - no_violencia: 1797 imágenes
#
# Proceso completado. Las imágenes representativas han sido guardadas.

# %% [markdown]
# # Average

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Función para cargar las imágenes y sus etiquetas
def load_images_and_labels(ruta_violentas, ruta_no_violentas):
    imagenes = []
    etiquetas = []
    
    # Cargar imágenes de la carpeta de violencia
    for filename in os.listdir(ruta_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de la carpeta de no violencia
    for filename in os.listdir(ruta_no_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_no_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)
    
    # Normalizar las imágenes
    imagenes = imagenes / 255.0
    
    return imagenes, etiquetas

# Función para cargar o crear el modelo
def load_or_create_model(model_path=None):
    if model_path and os.path.exists(model_path):
        # Cargar el modelo preentrenado desde el archivo .h5
        model = load_model(model_path)
        print("Modelo cargado desde:", model_path)
    else:
        # Crear un nuevo modelo base, si no hay modelo preentrenado
        base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(224, 224, 3))
        base_model.trainable = False  # Congelar el modelo base
        
        # Crear un nuevo modelo con capas personalizadas
        model = tf.keras.Sequential([
            base_model,
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(2, activation='softmax')  # Salida para 2 clases
        ])
        print("Nuevo modelo creado.")
        
    # Compilar el modelo
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Función para entrenar el modelo
def train_model(model, X_train, y_train, X_val, y_val, epochs=300, batch_size=16):
    model_history = model.fit(
        X_train, y_train,
        epochs=epochs,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(patience=10),
            tf.keras.callbacks.ModelCheckpoint('modelo_finetuned_average.h5', save_best_only=True),
            tf.keras.callbacks.TensorBoard(log_dir='./logs')
        ]
    )
    return model_history

# Función para graficar los resultados de entrenamiento
def plot_training_history(model_history):
    # Graficar precisión
    plt.plot(model_history.history['accuracy'])
    plt.plot(model_history.history['val_accuracy'])
    plt.title('Precisión durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Precisión')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

    # Graficar pérdida
    plt.plot(model_history.history['loss'])
    plt.plot(model_history.history['val_loss'])
    plt.title('Pérdida durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

# Función para graficar la matriz de confusión
def plot_confusion_matrix(model, X_val, y_val):
    preds = model.predict(X_val)
    predicted_labels = np.argmax(preds, axis=1)
    true_labels = np.argmax(y_val, axis=1)

    cm = confusion_matrix(true_labels, predicted_labels)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['No Violencia', 'Violencia'], yticklabels=['No Violencia', 'Violencia'])
    plt.xlabel('Predicción')
    plt.ylabel('Real')
    plt.show()

# Función para evaluar el modelo
def evaluate_model(model, X_val, y_val):
    test_loss, test_acc = model.evaluate(X_val, y_val)
    print(f"Precisión en conjunto de validación: {test_acc:.4f}")
    return test_acc

# Función principal para ejecutar el flujo completo de trabajo
def run_pipeline(ruta_violentas, ruta_no_violentas, model_path=None, epochs=300, batch_size=2):
    # Cargar los datos
    imagenes, etiquetas = load_images_and_labels(ruta_violentas, ruta_no_violentas)
    
    # Dividir en conjunto de entrenamiento y validación
    X_train, X_val, y_train, y_val = train_test_split(imagenes, etiquetas, test_size=0.2, random_state=2)
    
    # Cargar o crear el modelo
    model = load_or_create_model(model_path)

    # Entrenar el modelo
    model_history = train_model(model, X_train, y_train, X_val, y_val, epochs, batch_size)
    
    # Graficar resultados
    plot_training_history(model_history)
    
    # Evaluar y graficar la matriz de confusión
    evaluate_model(model, X_val, y_val)
    plot_confusion_matrix(model, X_val, y_val)
    
    # Guardar el modelo entrenado
    model.save('Modelo_average.h5')
    print("Modelo final guardado como 'Modelo_average.h5'.")

# Ejemplo de ejecución B
run_pipeline(
    ruta_violentas="../tipo3/average/violencia", 
    ruta_no_violentas="../tipo3/average/no_violencia", 
    model_path="modelo_mejorado_MobileNetV2.h5", 
    epochs=300, 
    batch_size=16
)
# Out:
# Modelo cargado desde: modelo_mejorado_MobileNetV2.h5
# Epoch 1/300
# 175/175 [==============================] - 8s 36ms/step - loss: 1.6588 - accuracy: 0.7249 - val_loss: 0.4733 - val_accuracy: 0.8739
# Epoch 2/300
# 175/175 [==============================] - 6s 32ms/step - loss: 0.4141 - accuracy: 0.8743 - val_loss: 0.3629 - val_accuracy: 0.8854
# Epoch 3/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.2101 - accuracy: 0.9269 - val_loss: 0.2078 - val_accuracy: 0.9241
# Epoch 4/300
# 175/175 [==============================] - 5s 30ms/step - loss: 0.1095 - accuracy: 0.9624 - val_loss: 0.1580 - val_accuracy: 0.9456
# Epoch 5/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0680 - accuracy: 0.9774 - val_loss: 0.1408 - val_accuracy: 0.9527
# Epoch 6/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0419 - accuracy: 0.9889 - val_loss: 0.1410 - val_accuracy: 0.9527
# Epoch 7/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0285 - accuracy: 0.9932 - val_loss: 0.1224 - val_accuracy: 0.9642
# Epoch 8/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0207 - accuracy: 0.9968 - val_loss: 0.1062 - val_accuracy: 0.9599
# Epoch 9/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0149 - accuracy: 0.9986 - val_loss: 0.1056 - val_accuracy: 0.9670
# Epoch 10/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0111 - accuracy: 0.9996 - val_loss: 0.1033 - val_accuracy: 0.9699
# Epoch 11/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0096 - accuracy: 0.9993 - val_loss: 0.0996 - val_accuracy: 0.9656
# Epoch 12/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0074 - accuracy: 0.9996 - val_loss: 0.0933 - val_accuracy: 0.9699
# Epoch 13/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0066 - accuracy: 0.9996 - val_loss: 0.0929 - val_accuracy: 0.9713
# Epoch 14/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9771
# Epoch 15/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0049 - accuracy: 0.9996 - val_loss: 0.0913 - val_accuracy: 0.9799
# Epoch 16/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9771
# Epoch 17/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9799
# Epoch 18/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9728
# Epoch 19/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9771
# Epoch 20/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9799
# Epoch 21/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9756
# Epoch 22/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0826 - val_accuracy: 0.9728
# Epoch 23/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9785
# Epoch 24/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9785
# Epoch 25/300
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9771
# Epoch 26/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9771
# Epoch 27/300
# 175/175 [==============================] - 5s 30ms/step - loss: 9.9937e-04 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9785
# Epoch 28/300
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 0.9728
# Epoch 29/300
# 175/175 [==============================] - 5s 31ms/step - loss: 7.6779e-04 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9799
# Epoch 30/300
# 175/175 [==============================] - 6s 32ms/step - loss: 6.4629e-04 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9785
# Epoch 31/300
# 175/175 [==============================] - 5s 31ms/step - loss: 5.6957e-04 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9785
# Epoch 32/300
# 175/175 [==============================] - 5s 31ms/step - loss: 5.2820e-04 - accuracy: 1.0000 - val_loss: 0.0796 - val_accuracy: 0.9799
# Epoch 33/300
# 175/175 [==============================] - 5s 31ms/step - loss: 4.5375e-04 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9771
# Epoch 34/300
# 175/175 [==============================] - 5s 31ms/step - loss: 4.2142e-04 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9756
# Epoch 35/300
# 175/175 [==============================] - 6s 32ms/step - loss: 3.8183e-04 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9771
# Epoch 36/300
# 175/175 [==============================] - 6s 32ms/step - loss: 3.3095e-04 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9771
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0781 - accuracy: 0.9771
# Precisión en conjunto de validación: 0.9771
# 22/22 [==============================] - 2s 41ms/step
# Modelo final guardado como 'Modelo_average.h5'.

# %%
import numpy as np
import os
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Directorios de las imágenes de prueba
ruta_test_violencia = "../test2/violencia"
ruta_test_no_violencia = "../test2/no_violencia"

# Función para cargar las imágenes y etiquetas de prueba
def cargar_datos_test(ruta_violencia, ruta_no_violencia):
    imagenes = []
    etiquetas = []

    # Cargar imágenes de violencia
    for filename in os.listdir(ruta_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de no violencia
    for filename in os.listdir(ruta_no_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_no_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)

    return imagenes, etiquetas

# Cargar datos de prueba
X_test, y_test = cargar_datos_test(ruta_test_violencia, ruta_test_no_violencia)

# Cargar el modelo preentrenado (asegúrate de tener el archivo .h5 del modelo final)
modelo_cargado = load_model("modelo_finetuned_average.h5")

# Normalizar las imágenes de prueba
X_test = X_test / 255.0  # Normalizar las imágenes de prueba

# Realizar predicciones con el modelo cargado
predicciones = modelo_cargado.predict(X_test)

# Convertir las predicciones a las clases (1 para violencia, 0 para no violencia)
predicciones_clase = np.argmax(predicciones, axis=1)
y_test_clase = np.argmax(y_test, axis=1)

# Calcular la matriz de confusión
matriz_confusion = confusion_matrix(y_test_clase, predicciones_clase)

# Imprimir la matriz de confusión
print("Matriz de Confusión:")
print(matriz_confusion)

# Graficar la matriz de confusión
plt.figure(figsize=(6, 6))
sns.heatmap(matriz_confusion, annot=True, fmt="d", cmap="Blues", xticklabels=["No Violencia", "Violencia"], yticklabels=["No Violencia", "Violencia"])
plt.title("Matriz de Confusión")
plt.ylabel('Clase Verdadera')
plt.xlabel('Clase Predicha')
plt.show()

# Calcular precisión, recall, f1-score (opcional)
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_clase, predicciones_clase)
recall = recall_score(y_test_clase, predicciones_clase)
f1 = f1_score(y_test_clase, predicciones_clase)

print(f"Precisión: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# 138/138 [==============================] - 9s 40ms/step
# Matriz de Confusión:
# [[2178   22]
#  [ 742 1458]]
# Precisión: 0.99
# Recall: 0.66
# F1-Score: 0.79

# %% [markdown]
# # Border

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Función para cargar las imágenes y sus etiquetas
def load_images_and_labels(ruta_violentas, ruta_no_violentas):
    imagenes = []
    etiquetas = []
    
    # Cargar imágenes de la carpeta de violencia
    for filename in os.listdir(ruta_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de la carpeta de no violencia
    for filename in os.listdir(ruta_no_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_no_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)
    
    # Normalizar las imágenes
    imagenes = imagenes / 255.0
    
    return imagenes, etiquetas

# Función para cargar o crear el modelo
def load_or_create_model(model_path=None):
    if model_path and os.path.exists(model_path):
        # Cargar el modelo preentrenado desde el archivo .h5
        model = load_model(model_path)
        print("Modelo cargado desde:", model_path)
    else:
        # Crear un nuevo modelo base, si no hay modelo preentrenado
        base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(224, 224, 3))
        base_model.trainable = False  # Congelar el modelo base
        
        # Crear un nuevo modelo con capas personalizadas
        model = tf.keras.Sequential([
            base_model,
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(2, activation='softmax')  # Salida para 2 clases
        ])
        print("Nuevo modelo creado.")
        
    # Compilar el modelo
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Función para entrenar el modelo
def train_model(model, X_train, y_train, X_val, y_val, epochs=1000, batch_size=16):
    model_history = model.fit(
        X_train, y_train,
        epochs=epochs,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(patience=10),
            tf.keras.callbacks.ModelCheckpoint('modelo_finetuned_border.h5', save_best_only=True),
            tf.keras.callbacks.TensorBoard(log_dir='./logs')
        ]
    )
    return model_history

# Función para graficar los resultados de entrenamiento
def plot_training_history(model_history):
    # Graficar precisión
    plt.plot(model_history.history['accuracy'])
    plt.plot(model_history.history['val_accuracy'])
    plt.title('Precisión durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Precisión')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

    # Graficar pérdida
    plt.plot(model_history.history['loss'])
    plt.plot(model_history.history['val_loss'])
    plt.title('Pérdida durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

# Función para graficar la matriz de confusión
def plot_confusion_matrix(model, X_val, y_val):
    preds = model.predict(X_val)
    predicted_labels = np.argmax(preds, axis=1)
    true_labels = np.argmax(y_val, axis=1)

    cm = confusion_matrix(true_labels, predicted_labels)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['No Violencia', 'Violencia'], yticklabels=['No Violencia', 'Violencia'])
    plt.xlabel('Predicción')
    plt.ylabel('Real')
    plt.show()

# Función para evaluar el modelo
def evaluate_model(model, X_val, y_val):
    test_loss, test_acc = model.evaluate(X_val, y_val)
    print(f"Precisión en conjunto de validación: {test_acc:.4f}")
    return test_acc

# Función principal para ejecutar el flujo completo de trabajo
def run_pipeline(ruta_violentas, ruta_no_violentas, model_path=None, epochs=1000, batch_size=32):
    # Cargar los datos
    imagenes, etiquetas = load_images_and_labels(ruta_violentas, ruta_no_violentas)
    
    # Dividir en conjunto de entrenamiento y validación
    X_train, X_val, y_train, y_val = train_test_split(imagenes, etiquetas, test_size=0.2, random_state=2)
    
    # Cargar o crear el modelo
    model = load_or_create_model(model_path)

    # Entrenar el modelo
    model_history = train_model(model, X_train, y_train, X_val, y_val, epochs, batch_size)
    
    # Graficar resultados
    plot_training_history(model_history)
    
    # Evaluar y graficar la matriz de confusión
    evaluate_model(model, X_val, y_val)
    plot_confusion_matrix(model, X_val, y_val)
    
    # Guardar el modelo entrenado
    model.save('Modelo_border.h5')
    print("Modelo final guardado como 'Modelo_border.h5'.")

# Ejemplo de ejecución B
run_pipeline(
    ruta_violentas="../tipo3/border/violencia", 
    ruta_no_violentas="../tipo3/border/no_violencia", 
    model_path="modelo_mejorado_MobileNetV2.h5", 
    epochs=1000, 
    batch_size=16
)
# Out:
# Modelo cargado desde: modelo_mejorado_MobileNetV2.h5
# Epoch 1/1000
# 6/6 [==============================] - 3s 281ms/step - loss: 1.9134 - accuracy: 0.6988 - val_loss: 1.2995 - val_accuracy: 0.5714
# Epoch 2/1000
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0898 - accuracy: 0.6867 - val_loss: 2.0622 - val_accuracy: 0.4762
# Epoch 3/1000
# 6/6 [==============================] - 0s 36ms/step - loss: 0.8934 - accuracy: 0.8193 - val_loss: 1.8730 - val_accuracy: 0.6190
# Epoch 4/1000
# 6/6 [==============================] - 1s 107ms/step - loss: 0.3166 - accuracy: 0.9157 - val_loss: 0.6489 - val_accuracy: 0.7619
# Epoch 5/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4234 - accuracy: 0.8795 - val_loss: 0.7824 - val_accuracy: 0.7143
# Epoch 6/1000
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1905 - accuracy: 0.9639 - val_loss: 1.7411 - val_accuracy: 0.6667
# Epoch 7/1000
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0910 - accuracy: 0.9759 - val_loss: 0.9461 - val_accuracy: 0.8095
# Epoch 8/1000
# 6/6 [==============================] - 1s 109ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.6352 - val_accuracy: 0.8095
# Epoch 9/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.6897 - val_accuracy: 0.8095
# Epoch 10/1000
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.8802 - val_accuracy: 0.8095
# Epoch 11/1000
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.0256 - val_accuracy: 0.8095
# Epoch 12/1000
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.0907 - val_accuracy: 0.7619
# Epoch 13/1000
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.0548 - val_accuracy: 0.8095
# Epoch 14/1000
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.9788 - val_accuracy: 0.8095
# Epoch 15/1000
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.9295 - val_accuracy: 0.8095
# Epoch 16/1000
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.9133 - val_accuracy: 0.8095
# Epoch 17/1000
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.9228 - val_accuracy: 0.8095
# Epoch 18/1000
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.9384 - val_accuracy: 0.8095
# 1/1 [==============================] - 0s 53ms/step - loss: 0.9388 - accuracy: 0.8095
# Precisión en conjunto de validación: 0.8095
# 1/1 [==============================] - 1s 765ms/step
# Modelo final guardado como 'Modelo_border.h5'.

# %%
import numpy as np
import os
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Directorios de las imágenes de prueba
ruta_test_violencia = "../test2/violencia"
ruta_test_no_violencia = "../test2/no_violencia"

# Función para cargar las imágenes y etiquetas de prueba
def cargar_datos_test(ruta_violencia, ruta_no_violencia):
    imagenes = []
    etiquetas = []

    # Cargar imágenes de violencia
    for filename in os.listdir(ruta_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de no violencia
    for filename in os.listdir(ruta_no_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_no_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)

    return imagenes, etiquetas

# Cargar datos de prueba
X_test, y_test = cargar_datos_test(ruta_test_violencia, ruta_test_no_violencia)

# Cargar el modelo preentrenado (asegúrate de tener el archivo .h5 del modelo final)
modelo_cargado = load_model("modelo_finetuned_border.h5")

# Normalizar las imágenes de prueba
X_test = X_test / 255.0  # Normalizar las imágenes de prueba

# Realizar predicciones con el modelo cargado
predicciones = modelo_cargado.predict(X_test)

# Convertir las predicciones a las clases (1 para violencia, 0 para no violencia)
predicciones_clase = np.argmax(predicciones, axis=1)
y_test_clase = np.argmax(y_test, axis=1)

# Calcular la matriz de confusión
matriz_confusion = confusion_matrix(y_test_clase, predicciones_clase)

# Imprimir la matriz de confusión
print("Matriz de Confusión:")
print(matriz_confusion)

# Graficar la matriz de confusión
plt.figure(figsize=(6, 6))
sns.heatmap(matriz_confusion, annot=True, fmt="d", cmap="Blues", xticklabels=["No Violencia", "Violencia"], yticklabels=["No Violencia", "Violencia"])
plt.title("Matriz de Confusión")
plt.ylabel('Clase Verdadera')
plt.xlabel('Clase Predicha')
plt.show()

# Calcular precisión, recall, f1-score (opcional)
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_clase, predicciones_clase)
recall = recall_score(y_test_clase, predicciones_clase)
f1 = f1_score(y_test_clase, predicciones_clase)

print(f"Precisión: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# 138/138 [==============================] - 6s 40ms/step
# Matriz de Confusión:
# [[1659  541]
#  [ 487 1713]]
# Precisión: 0.76
# Recall: 0.78
# F1-Score: 0.77

# %% [markdown]
# # Safe

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Función para cargar las imágenes y sus etiquetas
def load_images_and_labels(ruta_violentas, ruta_no_violentas):
    imagenes = []
    etiquetas = []
    
    # Cargar imágenes de la carpeta de violencia
    for filename in os.listdir(ruta_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de la carpeta de no violencia
    for filename in os.listdir(ruta_no_violentas):
        if filename.endswith(".jpg"):
            imagen = tf.keras.preprocessing.image.load_img(
                os.path.join(ruta_no_violentas, filename), target_size=(224, 224)
            )
            imagen = tf.keras.preprocessing.image.img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)
    
    # Normalizar las imágenes
    imagenes = imagenes / 255.0
    
    return imagenes, etiquetas

# Función para cargar o crear el modelo
def load_or_create_model(model_path=None):
    if model_path and os.path.exists(model_path):
        # Cargar el modelo preentrenado desde el archivo .h5
        model = load_model(model_path)
        print("Modelo cargado desde:", model_path)
    else:
        # Crear un nuevo modelo base, si no hay modelo preentrenado
        base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(224, 224, 3))
        base_model.trainable = False  # Congelar el modelo base
        
        # Crear un nuevo modelo con capas personalizadas
        model = tf.keras.Sequential([
            base_model,
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(2, activation='softmax')  # Salida para 2 clases
        ])
        print("Nuevo modelo creado.")
        
    # Compilar el modelo
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Función para entrenar el modelo
def train_model(model, X_train, y_train, X_val, y_val, epochs=300, batch_size=16):
    model_history = model.fit(
        X_train, y_train,
        epochs=epochs,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(patience=15),
            tf.keras.callbacks.ModelCheckpoint('modelo_finetuned_safe.h5', save_best_only=True),
            tf.keras.callbacks.TensorBoard(log_dir='./logs')
        ]
    )
    return model_history

# Función para graficar los resultados de entrenamiento
def plot_training_history(model_history):
    # Graficar precisión
    plt.plot(model_history.history['accuracy'])
    plt.plot(model_history.history['val_accuracy'])
    plt.title('Precisión durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Precisión')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

    # Graficar pérdida
    plt.plot(model_history.history['loss'])
    plt.plot(model_history.history['val_loss'])
    plt.title('Pérdida durante el entrenamiento')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend(['Entrenamiento', 'Validación'])
    plt.show()

# Función para graficar la matriz de confusión
def plot_confusion_matrix(model, X_val, y_val):
    preds = model.predict(X_val)
    predicted_labels = np.argmax(preds, axis=1)
    true_labels = np.argmax(y_val, axis=1)

    cm = confusion_matrix(true_labels, predicted_labels)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['No Violencia', 'Violencia'], yticklabels=['No Violencia', 'Violencia'])
    plt.xlabel('Predicción')
    plt.ylabel('Real')
    plt.show()

# Función para evaluar el modelo
def evaluate_model(model, X_val, y_val):
    test_loss, test_acc = model.evaluate(X_val, y_val)
    print(f"Precisión en conjunto de validación: {test_acc:.4f}")
    return test_acc

# Función principal para ejecutar el flujo completo de trabajo
def run_pipeline(ruta_violentas, ruta_no_violentas, model_path=None, epochs=300, batch_size=2):
    # Cargar los datos
    imagenes, etiquetas = load_images_and_labels(ruta_violentas, ruta_no_violentas)
    
    # Dividir en conjunto de entrenamiento y validación
    X_train, X_val, y_train, y_val = train_test_split(imagenes, etiquetas, test_size=0.2, random_state=2)
    
    # Cargar o crear el modelo
    model = load_or_create_model(model_path)

    # Entrenar el modelo
    model_history = train_model(model, X_train, y_train, X_val, y_val, epochs, batch_size)
    
    # Graficar resultados
    plot_training_history(model_history)
    
    # Evaluar y graficar la matriz de confusión
    evaluate_model(model, X_val, y_val)
    plot_confusion_matrix(model, X_val, y_val)
    
    # Guardar el modelo entrenado
    model.save('Modelo_safe.h5')
    print("Modelo final guardado como 'Modelo_safe.h5'.")

# Ejemplo de ejecución B
run_pipeline(
    ruta_violentas="../tipo3/safe/violencia", 
    ruta_no_violentas="../tipo3/safe/no_violencia", 
    model_path="modelo_mejorado_MobileNetV2.h5", 
    epochs=300, 
    batch_size=16
)
# Out:
# Modelo cargado desde: modelo_mejorado_MobileNetV2.h5
# Epoch 1/300
# 254/254 [==============================] - 16s 40ms/step - loss: 1.8381 - accuracy: 0.7275 - val_loss: 0.4835 - val_accuracy: 0.8611
# Epoch 2/300
# 254/254 [==============================] - 9s 34ms/step - loss: 0.3307 - accuracy: 0.8948 - val_loss: 0.2493 - val_accuracy: 0.9094
# Epoch 3/300
# 254/254 [==============================] - 9s 35ms/step - loss: 0.1693 - accuracy: 0.9387 - val_loss: 0.1816 - val_accuracy: 0.9379
# Epoch 4/300
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0976 - accuracy: 0.9662 - val_loss: 0.1488 - val_accuracy: 0.9488
# Epoch 5/300
# 254/254 [==============================] - 8s 33ms/step - loss: 0.0602 - accuracy: 0.9845 - val_loss: 0.1547 - val_accuracy: 0.9507
# Epoch 6/300
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0383 - accuracy: 0.9929 - val_loss: 0.1151 - val_accuracy: 0.9645
# Epoch 7/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0265 - accuracy: 0.9961 - val_loss: 0.1345 - val_accuracy: 0.9626
# Epoch 8/300
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0185 - accuracy: 0.9990 - val_loss: 0.1124 - val_accuracy: 0.9645
# Epoch 9/300
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0139 - accuracy: 0.9988 - val_loss: 0.1060 - val_accuracy: 0.9704
# Epoch 10/300
# 254/254 [==============================] - 8s 33ms/step - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.0982 - val_accuracy: 0.9695
# Epoch 11/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0097 - accuracy: 0.9990 - val_loss: 0.1052 - val_accuracy: 0.9714
# Epoch 12/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0075 - accuracy: 0.9995 - val_loss: 0.1011 - val_accuracy: 0.9734
# Epoch 13/300
# 254/254 [==============================] - 8s 33ms/step - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.0892 - val_accuracy: 0.9744
# Epoch 14/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0056 - accuracy: 0.9995 - val_loss: 0.0919 - val_accuracy: 0.9714
# Epoch 15/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0041 - accuracy: 0.9998 - val_loss: 0.0899 - val_accuracy: 0.9773
# Epoch 16/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9754
# Epoch 17/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0918 - val_accuracy: 0.9773
# Epoch 18/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9754
# Epoch 19/300
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9773
# Epoch 20/300
# 254/254 [==============================] - 8s 33ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9744
# Epoch 21/300
# 254/254 [==============================] - 8s 33ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9773
# Epoch 22/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9734
# Epoch 23/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.1185 - val_accuracy: 0.9645
# Epoch 24/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.0979 - val_accuracy: 0.9724
# Epoch 25/300
# 254/254 [==============================] - 8s 32ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0851 - val_accuracy: 0.9773
# Epoch 26/300
# 254/254 [==============================] - 8s 32ms/step - loss: 6.5440e-04 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9783
# Epoch 27/300
# 254/254 [==============================] - 8s 32ms/step - loss: 4.4525e-04 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9754
# Epoch 28/300
# 254/254 [==============================] - 8s 32ms/step - loss: 3.7020e-04 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9783
# Epoch 29/300
# 254/254 [==============================] - 8s 32ms/step - loss: 3.1146e-04 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9783
# Epoch 30/300
# 254/254 [==============================] - 8s 32ms/step - loss: 2.7328e-04 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9773
# Epoch 31/300
# 254/254 [==============================] - 8s 32ms/step - loss: 2.3752e-04 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9773
# Epoch 32/300
# 254/254 [==============================] - 8s 32ms/step - loss: 2.1192e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9783
# Epoch 33/300
# 254/254 [==============================] - 8s 32ms/step - loss: 1.8881e-04 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9773
# Epoch 34/300
# 254/254 [==============================] - 8s 32ms/step - loss: 1.6923e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9783
# Epoch 35/300
# 254/254 [==============================] - 8s 32ms/step - loss: 1.6163e-04 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9783
# Epoch 36/300
# 254/254 [==============================] - ETA: 0s - loss: 1.3527e-04 - accuracy: 1.0000

# %%
import numpy as np
import os
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Directorios de las imágenes de prueba
ruta_test_violencia = "../test2/violencia"
ruta_test_no_violencia = "../test2/no_violencia"

# Función para cargar las imágenes y etiquetas de prueba
def cargar_datos_test(ruta_violencia, ruta_no_violencia):
    imagenes = []
    etiquetas = []

    # Cargar imágenes de violencia
    for filename in os.listdir(ruta_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([1, 0])  # Etiqueta [1, 0] para violencia

    # Cargar imágenes de no violencia
    for filename in os.listdir(ruta_no_violencia):
        if filename.endswith(".jpg"):
            imagen = load_img(os.path.join(ruta_no_violencia, filename), target_size=(224, 224))
            imagen = img_to_array(imagen)
            imagenes.append(imagen)
            etiquetas.append([0, 1])  # Etiqueta [0, 1] para no violencia

    imagenes = np.array(imagenes)
    etiquetas = np.array(etiquetas)

    return imagenes, etiquetas

# Cargar datos de prueba
X_test, y_test = cargar_datos_test(ruta_test_violencia, ruta_test_no_violencia)

# Cargar el modelo preentrenado (asegúrate de tener el archivo .h5 del modelo final)
modelo_cargado = load_model("modelo_finetuned_safe.h5")

# Normalizar las imágenes de prueba
X_test = X_test / 255.0  # Normalizar las imágenes de prueba

# Realizar predicciones con el modelo cargado
predicciones = modelo_cargado.predict(X_test)

# Convertir las predicciones a las clases (1 para violencia, 0 para no violencia)
predicciones_clase = np.argmax(predicciones, axis=1)
y_test_clase = np.argmax(y_test, axis=1)

# Calcular la matriz de confusión
matriz_confusion = confusion_matrix(y_test_clase, predicciones_clase)

# Imprimir la matriz de confusión
print("Matriz de Confusión:")
print(matriz_confusion)

# Graficar la matriz de confusión
plt.figure(figsize=(6, 6))
sns.heatmap(matriz_confusion, annot=True, fmt="d", cmap="Blues", xticklabels=["No Violencia", "Violencia"], yticklabels=["No Violencia", "Violencia"])
plt.title("Matriz de Confusión")
plt.ylabel('Clase Verdadera')
plt.xlabel('Clase Predicha')
plt.show()

# Calcular precisión, recall, f1-score (opcional)
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_clase, predicciones_clase)
recall = recall_score(y_test_clase, predicciones_clase)
f1 = f1_score(y_test_clase, predicciones_clase)

print(f"Precisión: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# 138/138 [==============================] - 9s 26ms/step
# Matriz de Confusión:
# [[2180   20]
#  [ 712 1488]]
# Precisión: 0.99
# Recall: 0.68
# F1-Score: 0.80
